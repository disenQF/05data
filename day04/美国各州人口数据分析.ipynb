# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame, Index, MultiIndex
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# 首先导入文件，并查看数据样本

# %%
abbrevs = pd.read_csv('data/state-abbrevs.csv')
areas = pd.read_csv('data/state-areas.csv')
population = pd.read_csv('data/state-population.csv')
display(abbrevs.head(), areas.head(), population.head())
# Out:
#         state abbreviation
# 0     Alabama           AL
# 1      Alaska           AK
# 2     Arizona           AZ
# 3    Arkansas           AR
# 4  California           CA
#         state  area (sq. mi)
# 0     Alabama          52423
# 1      Alaska         656425
# 2     Arizona         114006
# 3    Arkansas          53182
# 4  California         163707
#   state/region     ages  year  population
# 0           AL  under18  2012   1117489.0
# 1           AL    total  2012   4817528.0
# 2           AL  under18  2010   1130966.0
# 3           AL    total  2010   4785570.0
# 4           AL  under18  2011   1125763.0

# %% [markdown]
# 合并pop与abbrevs两个DataFrame，分别依据state/region列和abbreviation列来合并。
# 为了保留所有信息，使用外合并

# %%
pop_abbr = pd.merge(population, abbrevs,
        left_on='state/region',
        right_on='abbreviation',
        how='outer')
pop_abbr.head()
# Out:
#   state/region     ages  year  population    state abbreviation
# 0           AL  under18  2012   1117489.0  Alabama           AL
# 1           AL    total  2012   4817528.0  Alabama           AL
# 2           AL  under18  2010   1130966.0  Alabama           AL
# 3           AL    total  2010   4785570.0  Alabama           AL
# 4           AL  under18  2011   1125763.0  Alabama           AL

# %% [markdown]
# 去除abbreviation的那一列（axis=1）

# %%
pop_abbr.drop('abbreviation', axis=1, inplace=True)
pop_abbr.head()
# Out:
#   state/region     ages  year  population    state
# 0           AL  under18  2012   1117489.0  Alabama
# 1           AL    total  2012   4817528.0  Alabama
# 2           AL  under18  2010   1130966.0  Alabama
# 3           AL    total  2010   4785570.0  Alabama
# 4           AL  under18  2011   1125763.0  Alabama

# %% [markdown]
# 查看存在缺失数据的列。
# 使用.isnull().any()，只有某一列存在一个缺失数据，就会显示True。

# %%
pop_abbr.isnull().any(axis=0)
# Out:
# state/region    False
# ages            False
# year            False
# population       True
# state            True
# dtype: bool

# %% [markdown]
# 查看缺失数据

# %%
pop_abbr.loc[:, pop_abbr.isnull().any(axis=0)]
# Out:
#        population    state
# 0       1117489.0  Alabama
# 1       4817528.0  Alabama
# 2       1130966.0  Alabama
# 3       4785570.0  Alabama
# 4       1125763.0  Alabama
# 5       4801627.0  Alabama
# 6       4757938.0  Alabama
# 7       1134192.0  Alabama
# 8       1111481.0  Alabama
# 9       4833722.0  Alabama
# 10      4672840.0  Alabama
# 11      1132296.0  Alabama
# 12      4718206.0  Alabama
# 13      1134927.0  Alabama
# 14      4569805.0  Alabama
# 15      1117229.0  Alabama
# 16      4628981.0  Alabama
# 17      1126798.0  Alabama
# 18      4530729.0  Alabama
# 19      1113662.0  Alabama
# 20      4503491.0  Alabama
# 21      1113083.0  Alabama
# 22      4467634.0  Alabama
# 23      1120409.0  Alabama
# 24      4480089.0  Alabama
# 25      1116590.0  Alabama
# 26      1121287.0  Alabama
# 27      4430141.0  Alabama
# 28      4452173.0  Alabama
# 29      1122273.0  Alabama
# ...           ...      ...
# 2514   71946051.0      NaN
# 2515  282162411.0      NaN
# 2516   72376189.0      NaN
# 2517  279040181.0      NaN
# 2518  284968955.0      NaN
# 2519   72671175.0      NaN
# 2520  287625193.0      NaN
# 2521   72936457.0      NaN
# 2522  290107933.0      NaN
# 2523   73100758.0      NaN
# 2524  292805298.0      NaN
# 2525   73297735.0      NaN
# 2526  295516599.0      NaN
# 2527   73523669.0      NaN
# 2528  298379912.0      NaN
# 2529   73757714.0      NaN
# 2530  301231207.0      NaN
# 2531   74019405.0      NaN
# 2532  304093966.0      NaN
# 2533   74104602.0      NaN
# 2534   73585872.0      NaN
# 2535  316128839.0      NaN
# 2536  306771529.0      NaN
# 2537   74134167.0      NaN
# 2538   74119556.0      NaN
# 2539  309326295.0      NaN
# 2540   73902222.0      NaN
# 2541  311582564.0      NaN
# 2542   73708179.0      NaN
# 2543  313873685.0      NaN
#
# [2544 rows x 2 columns]

# %% [markdown]
# 找到有哪些state/region使得state的值为NaN，使用unique()去重

# %%
pop_abbr.loc[pop_abbr.isnull().any(axis=1)]['state/region'].unique()
# Out:
# array(['PR', 'USA'], dtype=object)

# %% [markdown]
# 为找到的这些state/region的state项补上正确的值，从而去除掉state这一列的所有NaN！
# 记住这样清除缺失数据NaN的方法！

# %%
update = {
    'USA': 'United states of America',
    'PR': 'PUERTO RICO'
}
# 修改列名
pop_abbr.rename(columns={'state/region': 'region'},
                inplace=True)

# %%
pa = pd.merge(abbrevs,population,
              left_on='abbreviation',
              right_on='state/region', how='outer')

# %%
pa.drop('abbreviation', axis=1, inplace=True)

# %%
pa.isnull().any(axis=0)
# Out:
# state            True
# state/region    False
# ages            False
# year            False
# population       True
# dtype: bool

# %%
# 先查到某一列的 Series
# 通过： Series == '特征中的数据' 查询满足条件的所有索引数据(Series)
# 通过 查询结果的索引Series 作为.loc[行索引]，更新某一列的值
pa.loc[pa['state/region'] == 'USA', 'state'] = update['USA']
pa.loc[pa['state/region'] == 'PR', 'state'] = update['PR']

# %%
pa.loc[pa['state/region'] == 'USA']
# Out:
#                          state state/region     ages  year   population
# 2496  United states of America          USA  under18  1990   64218512.0
# 2497  United states of America          USA    total  1990  249622814.0
# 2498  United states of America          USA    total  1991  252980942.0
# 2499  United states of America          USA  under18  1991   65313018.0
# 2500  United states of America          USA  under18  1992   66509177.0
# 2501  United states of America          USA    total  1992  256514231.0
# 2502  United states of America          USA    total  1993  259918595.0
# 2503  United states of America          USA  under18  1993   67594938.0
# 2504  United states of America          USA  under18  1994   68640936.0
# 2505  United states of America          USA    total  1994  263125826.0
# 2506  United states of America          USA  under18  1995   69473140.0
# 2507  United states of America          USA  under18  1996   70233512.0
# 2508  United states of America          USA    total  1995  266278403.0
# 2509  United states of America          USA    total  1996  269394291.0
# 2510  United states of America          USA    total  1997  272646932.0
# 2511  United states of America          USA  under18  1997   70920738.0
# 2512  United states of America          USA  under18  1998   71431406.0
# 2513  United states of America          USA    total  1998  275854116.0
# 2514  United states of America          USA  under18  1999   71946051.0
# 2515  United states of America          USA    total  2000  282162411.0
# 2516  United states of America          USA  under18  2000   72376189.0
# 2517  United states of America          USA    total  1999  279040181.0
# 2518  United states of America          USA    total  2001  284968955.0
# 2519  United states of America          USA  under18  2001   72671175.0
# 2520  United states of America          USA    total  2002  287625193.0
# 2521  United states of America          USA  under18  2002   72936457.0
# 2522  United states of America          USA    total  2003  290107933.0
# 2523  United states of America          USA  under18  2003   73100758.0
# 2524  United states of America          USA    total  2004  292805298.0
# 2525  United states of America          USA  under18  2004   73297735.0
# 2526  United states of America          USA    total  2005  295516599.0
# 2527  United states of America          USA  under18  2005   73523669.0
# 2528  United states of America          USA    total  2006  298379912.0
# 2529  United states of America          USA  under18  2006   73757714.0
# 2530  United states of America          USA    total  2007  301231207.0
# 2531  United states of America          USA  under18  2007   74019405.0
# 2532  United states of America          USA    total  2008  304093966.0
# 2533  United states of America          USA  under18  2008   74104602.0
# 2534  United states of America          USA  under18  2013   73585872.0
# 2535  United states of America          USA    total  2013  316128839.0
# 2536  United states of America          USA    total  2009  306771529.0
# 2537  United states of America          USA  under18  2009   74134167.0
# 2538  United states of America          USA  under18  2010   74119556.0
# 2539  United states of America          USA    total  2010  309326295.0
# 2540  United states of America          USA  under18  2011   73902222.0
# 2541  United states of America          USA    total  2011  311582564.0
# 2542  United states of America          USA  under18  2012   73708179.0
# 2543  United states of America          USA    total  2012  313873685.0

# %%
pop_abbr.head()
# Out:
#   region     ages    year  population    state
# 0     AL  under18  2012.0   1117489.0  Alabama
# 1     AL    total  2012.0   4817528.0  Alabama
# 2     AL  under18  2010.0   1130966.0  Alabama
# 3     AL    total  2010.0   4785570.0  Alabama
# 4     AL  under18  2011.0   1125763.0  Alabama

# %%
pa_copy = pop_abbr.query('region == "USA"')
pa_copy['state'] = 'United states of America'

pa_copy_2 = pop_abbr.query('region == "PR"')
pa_copy_2['state'] = 'PUERTO RICO'

# 使用有数据的DataFrame（右表）， 更新有Nan的DataFrame(左表)，
pop_abbr.update(pa_copy)
pop_abbr.update(pa_copy_2)
# Out:
# /Users/apple/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/apple/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
pop_abbr.isnull().any(axis=0)
# Out:
# region        False
# ages          False
# year          False
# population     True
# state         False
# dtype: bool

# %% [markdown]
# 合并各州面积数据areas，使用左合并。
# 思考一下为什么使用左合并？

# %%
areas.head()
# Out:
#         state  area (sq. mi)
# 0     Alabama          52423
# 1      Alaska         656425
# 2     Arizona         114006
# 3    Arkansas          53182
# 4  California         163707

# %%
# 保留所有的州（左合并）
full = pd.merge(pop_abbr,areas, how='left')
full.head()
# Out:
#   region     ages    year  population    state  area (sq. mi)
# 0     AL  under18  2012.0   1117489.0  Alabama        52423.0
# 1     AL    total  2012.0   4817528.0  Alabama        52423.0
# 2     AL  under18  2010.0   1130966.0  Alabama        52423.0
# 3     AL    total  2010.0   4785570.0  Alabama        52423.0
# 4     AL  under18  2011.0   1125763.0  Alabama        52423.0

# %% [markdown]
# 继续寻找存在缺失数据的列

# %%
full.isnull().any(axis=0)
# Out:
# region           False
# ages             False
# year             False
# population        True
# state            False
# area (sq. mi)     True
# dtype: bool

# %% [markdown]
# 我们会发现area(sq.mi)这一列有缺失数据，为了找出是哪一行，我们需要找出是哪个state没有数据

# %%
full.loc[full.isnull().any(axis=1)]['state'].unique()
# Out:
# array(['PUERTO RICO', 'United states of America'], dtype=object)

# %% [markdown]
# 找出2010年的全民人口数据

# %%
q = 'year == 2010 & ages == "total" & region != "USA"'
full.query(q)['population'].sum()
# Out:
# 313047503.0

# %% [markdown]
# 对查询结果进行处理，以state列作为新的行索引

# %%
full.head()
# Out:
#   region     ages    year  population    state  area (sq. mi)
# 0     AL  under18  2012.0   1117489.0  Alabama        52423.0
# 1     AL    total  2012.0   4817528.0  Alabama        52423.0
# 2     AL  under18  2010.0   1130966.0  Alabama        52423.0
# 3     AL    total  2010.0   4785570.0  Alabama        52423.0
# 4     AL  under18  2011.0   1125763.0  Alabama        52423.0

# %%
# 将列转成DataFrame的行索引
full.set_index('state', inplace=True)

# %%
full.head()
# Out:
#         region     ages    year  population  area (sq. mi)
# state
# Alabama     AL  under18  2012.0   1117489.0        52423.0
# Alabama     AL    total  2012.0   4817528.0        52423.0
# Alabama     AL  under18  2010.0   1130966.0        52423.0
# Alabama     AL    total  2010.0   4785570.0        52423.0
# Alabama     AL  under18  2011.0   1125763.0        52423.0

# %% [markdown]
# 计算人口密度。注意是Series/Series，其结果还是一个Series

# %%
full_pa = full.query('ages == "total" & region != "USA" & year == 2013')
full_pa['density'] = np.round(full_pa['population'] / full_pa['area (sq. mi)'], 2)
# Out:
# /Users/apple/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
full_pa.head()
# Out:
#            region   ages    year  population  area (sq. mi)  density
# state
# Alabama        AL  total  2013.0   4833722.0        52423.0    92.21
# Alaska         AK  total  2013.0    735132.0       656425.0     1.12
# Arizona        AZ  total  2013.0   6626624.0       114006.0    58.13
# Arkansas       AR  total  2013.0   2959373.0        53182.0    55.65
# California     CA  total  2013.0  38332521.0       163707.0   234.15

# %% [markdown]
# 排序，并找出2013年人口密度最高的五个州

# %%
full_pa.sort_values('density',
                    axis=0,
                    ascending=False)[:5]
# Out:
#                      region   ages    year  population  area (sq. mi)  density
# state
# District of Columbia     DC  total  2013.0    646449.0           68.0  9506.60
# New Jersey               NJ  total  2013.0   8899339.0         8722.0  1020.33
# Rhode Island             RI  total  2013.0   1051511.0         1545.0   680.59
# Connecticut              CT  total  2013.0   3596080.0         5544.0   648.64
# Massachusetts            MA  total  2013.0   6692824.0        10555.0   634.09

# %% [markdown]
# 排序，并找出2013年人口密度最低的五个州

# %%
# 排序-按数值排序， by 根据axis轴的标签，进行升序或降序排序
full_pa.sort_values('density',
                    axis=0,
                    ascending=True)[:5]
# Out:
#              region   ages    year  population  area (sq. mi)  density
# state
# Alaska           AK  total  2013.0    735132.0       656425.0     1.12
# Wyoming          WY  total  2013.0    582658.0        97818.0     5.96
# Montana          MT  total  2013.0   1015165.0       147046.0     6.90
# North Dakota     ND  total  2013.0    723393.0        70704.0    10.23
# South Dakota     SD  total  2013.0    844877.0        77121.0    10.96
